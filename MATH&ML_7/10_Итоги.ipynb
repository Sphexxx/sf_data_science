# %% [markdown]
# ⭐ Вы завершили изучение модуля, посвящённого теории вероятностей — поздравляем!
#
# На протяжении этого модуля вы усвоили большой объём новой информации и освоили много новых алгоритмов для решения задач.
#
# + Узнали основные понятия, связанные с теорией вероятностей: теперь вы можете переводить ваши вероятностные задачи на математический язык, лучше понимать статьи, описывающие алгоритмы машинного обучения, и правильно оперировать терминами.
# + Научились вычислять вероятности как для совсем элементарных задач, так и для очень сложных: теперь вы сможете грамотно принимать решения, основываясь на вероятностных выводах.
# + Самостоятельно реализовали алгоритм классификации, основанный на теореме Байеса: в ваш арсенал добавился ещё один способ классифицировать тексты или табличные данные, а также теперь вы понимаете разницу между вариациями НБК и можете подобрать подходящую.
# + Познакомились со случайной величиной, а также с тем, как можно задать её распределение и с помощью каких характеристик можно его оценить: это поможет вам анализировать числовые массивы, которые всегда есть в данных.
# + Узнали, какие есть самые популярные дискретные и непрерывные распределения и какие ситуации из жизни они описывают: так как на основе распределений разработаны различные алгоритмы и статистические тесты, то теперь вы сможете в них успешно разобраться в будущем.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
