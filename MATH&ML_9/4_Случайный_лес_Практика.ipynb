# %% [markdown]
# ✍ В предыдущем юните мы познакомились с теоретической основой случайного леса, а в этом закрепим пройденный материал на практике.
#
# Пожалуй, каждый из нас практически ежедневно смотрит прогноз погоды: будет сегодня тепло или холодно, брать ли зонт? Мы расстраиваемся, если внезапно идёт дождь, а мы оказались к этому не готовы. Иногда можно понять, что будет дождь, просто взглянув на небо, но часто такие предположения оказываются неверными. Надёжнее всего пользоваться прогнозами, которые публикуют специалисты. А задумывались ли вы, как формируются эти прогнозы?
#
# Да-да, здесь тоже не обошлось без машинного обучения. В этом юните мы с вами немного коснёмся метеорологии, чтобы предсказать, будет ли дождь в Австралии. Попутно вы узнаете, какие факторы влияют на вероятность дождя — возможно, вы научитесь предсказывать его точнее, чем метеорологические службы, и больше никогда не окажетесь в нужный момент без зонта.
#
# Давайте посмотрим, с какими данными нам предстоит работать.

# %%
import pandas as pd
import numpy as np

from sklearn import tree
from sklearn import model_selection
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("weatherAUS.csv", parse_dates=["Date"])
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65298 entries, 0 to 65297
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           65298 non-null  datetime64[ns]
#  1   Location       65298 non-null  object
#  2   MinTemp        64679 non-null  float64
#  3   MaxTemp        64848 non-null  float64
#  4   Rainfall       63842 non-null  float64
#  5   Evaporation    28173 non-null  float64
#  6   Sunshine       21365 non-null  float64
#  7   WindGustDir    59227 non-null  object
#  8   WindGustSpeed  59235 non-null  float64
#  9   WindDir9am     58624 non-null  object
#  10  WindDir3pm     62535 non-null  object
#  11  WindSpeed9am   63929 non-null  float64
#  12  WindSpeed3pm   63311 non-null  float64
#  13  Humidity9am    64016 non-null  float64
#  14  Humidity3pm    63559 non-null  float64
#  15  Pressure9am    55209 non-null  float64
#  16  Pressure3pm    55261 non-null  float64
#  17  Cloud9am       37937 non-null  float64
#  18  Cloud3pm       37159 non-null  float64
#  19  Temp9am        64352 non-null  float64
#  20  Temp3pm        63837 non-null  float64
#  21  RainToday      63841 non-null  object
#  22  RainTomorrow   63842 non-null  object
# dtypes: datetime64[ns](1), float64(16), object(6)
# memory usage: 11.5+ MB

# %% [markdown]
# + Date — дата, в которую зафиксировано наблюдение;
# + Location — местонахождение метеорологической станции;
# + MinTemp — минимальная температура (℃);
# + MaxTemp — максимальная температура (℃);
# + Rainfall — количество осадков (дождь) за сутки (мм);
# + Evaporation — количество испарений до 9 утра (мм);
# + Sunshine — количество часов в сутках, когда светило солнце;
# + WindGustDir — направление самого сильного порыва ветра за последние 24 часа;
# + WindGustSpeed — скорость самого сильного порыва ветра за последние 24 часа;
# + WindDir9am — направление ветра в 9 утра;
# + WindDir3pm — направление ветра в 3 часа дня;
# + WindSpeed9am — скорость ветра в 9 часов утра;
# + WindSpeed3pm — скорость ветра в 3 часа дня;
# + Humidity9am — влажность в 9 утра;
# + Humidity3pm — влажность в 3 часа дня;
# + Pressure9am — атмосферное давление в 9 утра;
# + Pressure3pm — атмосферное давление в 3 часа дня;
# + Cloud9am — часть неба, закрытая облаками, в 9 утра;
# + Cloud3pm — часть неба, закрытая облаками, в 3 часа дня;
# + Temp9am — температура в 9 утра;
# + Temp3pm — температура в 3 часа дня;
# + RainToday — наличие дождя в этот день;
# + RainTomorrow — наличие дождя на следующий день.

# %% [markdown]
# Данные содержат 23 признака и 145 460 наблюдений. Из этих 23 признаков шесть — категориальные, в одном записана дата, а остальные являются непрерывными числовыми данными.
#
# + Примеры числовых признаков: температура, скорость ветра, влажность, облачность, атмосферное давление в разное время суток, количество осадков, испарение, количество часов с солнечной погодой.
# + Примеры категориальных признаков: местоположение, направление ветра в разное время суток, наличие дождя сегодня или завтра.
#
# **Целевой переменной** является столбец *RainTomorrow*. Значение этой переменной мы и будем пытаться предсказать.

# %% [markdown]
# ## Задание 4.1
#
# Сколько суммарно пропусков в данных?

# %%
df.isnull().sum().sum()
# Out:
# 192477

# %% [markdown]
# Можно отметить, что в данных много пропусков, но для нас это не проблема, так как случайный лес прекрасно работает в таких ситуациях, и скоро у нас будет возможность в этом убедиться.

# %% [markdown]
# ## Задание 4.2
#
# В некоторых признаках пропусков более 40 % — удалите такие признаки. Сколько их было?

# %%
round(df.isna().sum() / len(df), 3)
df.drop(['Evaporation','Sunshine','Cloud3pm'], axis = 1, inplace = True)

# %% [markdown]
# ## Задание 4.3
#
# Теперь обработаем признаки *RainToday* и *RainTomorrow* таким образом, чтобы вместо *yes* было значение 1, а вместо *no* — значение 0. Обратите внимание на то, что в признаке *RainTomorrow* присутствуют пропуски, и их трогать не нужно, они должны остаться пропусками. Поэтому обрабатывайте столбцы таким образом, чтобы не видоизменить пропущенные значения.
#
# Вычислите среднее арифметическое для преобразованного признака *RainToday* и запишите его в ответ, предварительно округлив до двух знаков после точки-разделителя.

# %%
df.RainToday = df.RainToday.map({'No': 0, 'Yes': 1})
df.RainTomorrow = df.RainTomorrow.map({'No': 0, 'Yes': 1})

# %%
df['RainToday'].mean()
# Out:
# 0.22391566548143044

# %% [markdown]
# ## Задание 4.4
#
# Обработайте признак Date таким образом, чтобы выделить в отдельный признак Month (номер месяца). Изначальный признак Date удалите. Определите, в какой месяц в среднем за день выпадает больше всего дождей. В качестве ответа введите порядковый номер месяца.

# %%
df.Date = pd.to_datetime(df.Date)
df['Month'] = df.Date.dt.month
df.drop('Date', axis = 1, inplace = True)
df_season = df.groupby('Month').mean()
df_season[['RainToday']]
# Out:
#        RainToday
# Month
# 1       0.202182
# 2       0.238662
# 3       0.239487
# 4       0.235422
# 5       0.190921
# 6       0.268039
# 7       0.241012
# 8       0.214095
# 9       0.202437
# 10      0.200417
# 11      0.232139
# 12      0.225660

# %% [markdown]
# ## Задание 4.5
#
# Обработайте оставшиеся категориальные признаки. С помощью метода get_dummies с настройками по умолчанию создайте dummy-переменные для всех категориальных признаков (их пять), которые есть в данных на этот момент.
#
# Кодировку признаков важно выполнить именно в следующем порядке: categoricals = ['Month', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']. Это необходимо для того, чтобы ваши дальнейшие ответы сходились с нашим решением, так как алгоритм случайного леса, который мы будем использовать в дальнейшем, чувствителен к порядку столбцов.
#
# Сколько теперь признаков в данных, если считать целевую переменную?

# %%
categoricals = ['Month', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']
df_dummies = pd.get_dummies(df, columns=categoricals)
df_dummies.shape
# Out:
# (65298, 97)

# %% [markdown]
# ## Задание 4.6
#
# Осталось совсем немного. Удалите все строки, где есть пропуски. Далее разбейте данные на обучающую и тестовую выборки в соотношении 70/30, в качестве значения параметра random_state возьмите число 31.
#
# Каково среднее значение целевой переменной на тестовой выборке? Ответ округлите до двух знаков после точки-разделителя.

# %%
df_dummies.dropna(inplace=True)
X = df_dummies.drop('RainTomorrow', axis = 1)
y = df_dummies['RainTomorrow']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 31)
y_test.mean()
# Out:
# 0.24922950482843642

# %% [markdown]
# ## Задание 4.7
#
# Теперь давайте вспомним про бутстреп. Он не понадобится нам для решения этой задачи, но будет полезно реализовать его «вручную».
#
# Сделайте оценку стандартного отклонения для среднего значения минимальной температуры для обучающей выборки (то есть для среднего значения по признаку MinTemp). Для этого сгенерируйте 1000 случайных выборок из наших данных — каждая из них должна быть такого же объёма, как и обучающая выборка. Для генерации выборки используйте np.random.randint(): сгенерируйте необходимое количество индексов и по ним извлеките соответствующие элементы выборки. Случайность фиксируйте с помощью np.random.seed(31).
#
# Для каждой выборки вычислите среднее значение, а после найдите стандартное отклонение для этих значений. Ответ округлите до двух знаков после точки-разделителя.

# %%
np.random.seed(31)

samples = X_train["MinTemp"].values[
    np.random.randint(0, len(X_train), (1000, len(X_train)))
]

round(np.std(np.mean(samples, axis=1)), 2)
# Out:
# 0.04

# %% [markdown]
# ## Задание 4.8
#
# Теперь можно перейти к обучению прогностических моделей. Начнём с того, что построим простейшую логистическую регрессию (без настройки гиперпараметров). Это будет та модель, с качеством которой мы будем сравнивать результаты, полученные далее, чтобы оценить превосходство случайного леса над простыми методами.
#
# В качестве ответа введите значение метрики roc_auc на тестовой выборке. Ответ округлите до двух знаков после точки-разделителя.

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
roc_auc_score(y_test, preds_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7200277643536023

# %% [markdown]
# ## Задание 4.9

# %%
params = {
    'max_leaf_nodes': list(range(2, 10)), 
    'min_samples_split': [2, 3, 4], 
    'max_depth': [5,7,9,11]
}

grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=42), params, verbose=3, cv=3)
grid_search_cv.fit(X_train, y_train)
print(grid_search_cv.best_params_)

clf = DecisionTreeClassifier(max_depth = 5, max_leaf_nodes = 9, min_samples_split = 2, random_state=42)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.830 total time=   0.2s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.818 total time=   0.2s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.815 total time=   0.2s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.818 total time=   0.2s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.818 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.815 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.821 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.816 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.830 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.823 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.826 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.830 total time=   0.1s
# {'max_depth': 5, 'max_leaf_nodes': 9, 'min_samples_split': 2}
# 0.69

# %% [markdown]
# ## Задание 4.10

# %%
clf = RandomForestClassifier(n_estimators = 100, random_state=31)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# 0.72

# %% [markdown]
# ## Задание 4.11

# %%
params = {
    'max_features': [4, 5, 6, 7], 
    'min_samples_leaf': [3, 5, 7, 9, 11], 
    'max_depth': [5, 10, 15]
}
grid_search_cv = GridSearchCV(RandomForestClassifier(random_state=31), params, verbose=3, cv=3)
grid_search_cv.fit(X_train, y_train)
print(grid_search_cv.best_params_)
clf = RandomForestClassifier(max_depth=15, max_features=7, min_samples_leaf=3, random_state=31)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.764 total time=   1.0s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.763 total time=   1.0s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.762 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.762 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.763 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.763 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.763 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.764 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.763 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.762 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.763 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.764 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.763 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.763 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.762 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.786 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.786 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.789 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.786 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.782 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.789 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.784 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.786 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.790 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.781 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.783 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.787 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.783 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.785 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.787 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.783 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.784 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.789 total time=   1.4s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.787 total time=   1.0s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.785 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.787 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.784 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.782 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.786 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.786 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.783 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.786 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.789 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.781 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.788 total time=   1.0s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.802 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.800 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.805 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.802 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.799 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.802 total time=   1.0s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.800 total time=   1.0s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.799 total time=   1.0s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.804 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.801 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.798 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.804 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.802 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.797 total time=   1.5s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.802 total time=   1.0s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.809 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.805 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.815 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.812 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.808 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.815 total time=   1.0s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.809 total time=   1.1s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.807 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.812 total time=   1.5s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.809 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.801 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.808 total time=   1.0s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.808 total time=   1.0s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.807 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.811 total time=   1.0s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.821 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.819 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.824 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.818 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.817 total time=   2.1s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.827 total time=   1.9s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.816 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.815 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.825 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.815 total time=   1.1s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.815 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.824 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.817 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.814 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.821 total time=   1.8s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.823 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.821 total time=   1.5s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.830 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.825 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.822 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.827 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.823 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.819 total time=   1.7s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.827 total time=   2.0s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.824 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.820 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.830 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.822 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.820 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.824 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.827 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.827 total time=   1.9s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.835 total time=   2.1s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.829 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.826 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.834 total time=   1.4s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.827 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.829 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.831 total time=   1.5s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.827 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.824 total time=   2.3s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.834 total time=   2.1s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.826 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.825 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.832 total time=   1.4s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.823 total time=   1.3s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.821 total time=   1.3s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.829 total time=   1.5s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.823 total time=   2.2s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.820 total time=   1.4s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.829 total time=   1.4s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.822 total time=   1.4s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.819 total time=   1.4s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.825 total time=   1.2s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.821 total time=   1.2s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.815 total time=   1.3s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.825 total time=   1.7s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.819 total time=   1.9s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.817 total time=   1.4s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.824 total time=   1.2s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.831 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.833 total time=   1.7s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.835 total time=   1.7s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.832 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.828 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.832 total time=   1.9s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.828 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.829 total time=   1.6s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.834 total time=   1.5s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.826 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.825 total time=   1.5s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.831 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.827 total time=   2.2s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.827 total time=   1.9s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.829 total time=   2.0s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.833 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.833 total time=   1.7s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.840 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.833 total time=   2.3s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.833 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.838 total time=   1.7s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.833 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.831 total time=   1.8s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.836 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.830 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.831 total time=   2.2s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.834 total time=   1.9s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.831 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.828 total time=   1.6s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.834 total time=   1.6s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.834 total time=   2.1s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.835 total time=   2.2s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.839 total time=   2.9s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.834 total time=   1.9s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.835 total time=   2.0s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.840 total time=   2.1s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.833 total time=   2.0s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.836 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.837 total time=   2.5s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.831 total time=   1.9s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.834 total time=   2.0s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.835 total time=   2.5s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.833 total time=   1.8s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.832 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.836 total time=   2.3s
# {'max_depth': 15, 'max_features': 7, 'min_samples_leaf': 5}
# 0.7

# %% [markdown]
# ## Задание 4.12

# %%
feature_names = [x for x in df_dummies if x != 'RainTomorrow']
pd.DataFrame({'feat': feature_names,
              'coef': clf.feature_importances_}).sort_values(by='coef', ascending=False)
# Out:
#                       feat      coef
# 7              Humidity3pm  0.255095
# 10                Cloud9am  0.073442
# 2                 Rainfall  0.061021
# 6              Humidity9am  0.060969
# 3            WindGustSpeed  0.056794
# ..                     ...       ...
# 27  Location_BadgerysCreek  0.000000
# 44    Location_Tuggeranong  0.000000
# 36      Location_Newcastle  0.000000
# 37      Location_NorahHead  0.000000
# 39        Location_Penrith  0.000000
#
# [96 rows x 2 columns]

# %% [markdown]
# ⭐ Итак, вы потренировались решать задачу классификации с помощью случайного леса, рассмотрели на практике некоторые важные свойства этого ансамбля и узнали, от каких факторов зависит, будет ли завтра дождь — весьма полезная информация.
#
# Однако, как вы помните, случайный лес — это не единственный вид ансамблей. Уже в следующем юните мы продолжим наше погружение в этот класс алгоритмов и изучим бустинг →
