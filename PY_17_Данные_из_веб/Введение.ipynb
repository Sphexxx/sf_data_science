# %% [markdown]
# # Библиотека requests

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %% [markdown]
# ## РАБОТАЕМ С ОТВЕТОМ

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2022-06-09T11:30:00+03:00",
#     "PreviousDate": "2022-06-08T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/06\/08\/daily_json.js",
#     "Timestamp": "2022-06-09T11:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 43.3763,
#             "Previous": 43.7485
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 35.4284,
#             "Previous": 35.8568
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 75.7671,
#             "Previous": 76.5431
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 13.9809,
#             "Previous": 14.0495
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 23.2263,
#             "Previous": 23.4088
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 32.8326,
#             "Previous": 33.4283
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 12.3151,
#             "Previous": 12.7428
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 16.4959,
#             "Previous": 16.7096
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 76.8903,
#             "Previous": 77.84
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 10,
#             "Name": "Датских крон",
#             "Value": 86.3165,
#             "Previous": 87.9261
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 60.2282,
#             "Previous": 60.9565
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 63.938,
#             "Previous": 64.5699
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 77.6583,
#             "Previous": 78.4874
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 14.0258,
#             "Previous": 14.1142
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 47.9715,
#             "Previous": 48.5168
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 75.7498,
#             "Previous": 76.6748
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 10,
#             "Name": "Китайских юаней",
#             "Value": 92.6609,
#             "Previous": 93.0036
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 31.6681,
#             "Previous": 32.0051
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 63.053,
#             "Previous": 64.7392
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 14.1261,
#             "Previous": 14.1832
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 13.0378,
#             "Previous": 13.1769
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 80.9931,
#             "Previous": 82.2699
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 43.7991,
#             "Previous": 44.2034
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 53.2993,
#             "Previous": 53.4706
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 36.0141,
#             "Previous": 36.7788
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 17.2081,
#             "Previous": 17.4161
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 54.5203,
#             "Previous": 55.2558
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 20.4307,
#             "Previous": 20.6293
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 25.9582,
#             "Previous": 26.4534
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 61.4147,
#             "Previous": 62.8625
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 61.5327,
#             "Previous": 62.5067
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 39.2427,
#             "Previous": 39.5336
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 48.0365,
#             "Previous": 48.4666
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 45.3184,
#             "Previous": 46.0988
#         }
#     }
# }

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-06-09T11:30:00+03:00',
#  'PreviousDate': '2022-06-08T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/06/08/daily_json.js',
#  'Timestamp': '2022-06-09T11:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 14.0495,
#                     'Value': 13.9809},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 43.7485,
#                     'Value': 43.3763},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 35.8568,
#                     'Value': 35.4284},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 33.4283,
#                     'Value': 32.8326},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 12.7428,
#                     'Value': 12.3151},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 23.4088,
#                     'Value': 23.2263},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 48.5168,
#                     'Value': 47.9715},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 62.5067,
#                     'Value': 61.5327},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайских юаней',
#                     'Nominal': 10,
#                     'NumCode': '156',
#                     'Previous': 93.0036,
#                     'Value': 92.6609},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 26.4534,
#                     'Value': 25.9582},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датских крон',
#                     'Nominal': 10,
#                     'NumCode': '208',
#                     'Previous': 87.9261,
#                     'Value': 86.3165},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 64.5699,
#                     'Value': 63.938},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 76.5431,
#                     'Value': 75.7671},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 77.84,
#                     'Value': 76.8903},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 16.7096,
#                     'Value': 16.4959},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 78.4874,
#                     'Value': 77.6583},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 46.0988,
#                     'Value': 45.3184},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 76.6748,
#                     'Value': 75.7498},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 48.4666,
#                     'Value': 48.0365},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 14.1142,
#                     'Value': 14.0258},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 32.0051,
#                     'Value': 31.6681},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 64.7392,
#                     'Value': 63.053},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 14.1832,
#                     'Value': 14.1261},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 13.1769,
#                     'Value': 13.0378},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 62.8625,
#                     'Value': 61.4147},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 44.2034,
#                     'Value': 43.7991},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 53.4706,
#                     'Value': 53.2993},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 17.4161,
#                     'Value': 17.2081},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 36.7788,
#                     'Value': 36.0141},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 20.6293,
#                     'Value': 20.4307},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 60.9565,
#                     'Value': 60.2282},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 55.2558,
#                     'Value': 54.5203},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 82.2699,
#                     'Value': 80.9931},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 39.5336,
#                     'Value': 39.2427}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 64.5699,
#  'Value': 63.938}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# # 4. Парсинг сайтов

# %% [markdown]
# ## ОСНОВЫ HTML

# %% [markdown]
# ### HTML (англ. HyperText Markup Language, рус. язык гипертекстовой разметки) — стандартизированный язык разметки документов в интернете. Большинство веб-страниц содержат описание разметки на языке HTML. Язык HTML интерпретируется браузерами. Полученный в результате интерпретации текст отображается на экране монитора компьютера или мобильного устройства.

# %% [markdown]
# + существуют теги с разными именами;
# + у тегов бывают атрибуты, такие как class и id;
# + теги образуют иерархическую структуру, то есть одни теги вложены в другие.

# %% [markdown]
# ## ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!doctype html>
# <html class="old-town-road no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#     <link rel="icon" href="/i/favicon-bw.png" />
#
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#         <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1649061972">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#     <link rel="stylesheet" href="/js/tests/scopus/css/style.css">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#
#
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
#
#
#
#
#
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2022/06/07/breathing-lessons" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/07/breathing-lessons" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Мейлан Хан &laquo;Чудо дыхания. Как работают наши легкие и как поддержать их здоровье&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis" class="container-link">
#                     <div class="heading"><span>Эксперименты</span></div>
#                     <div class="link"><span>У меня в глазу спектрометр: инструкция по разложению света невооруженным взглядом</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/03/tastes-like-moon" class="container-link">
#                     <div class="heading"><span>Хлеб и вино</span></div>
#                     <div class="link"><span>На вкус как Луна: зачем NASA кормило тараканов грунтом</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Игорь Лисов &laquo;Разведчики внешних планет&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Никлас Брендборг &laquo;Загадка нестареющей медузы&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/05/27/prehistoric-planet-forests" class="container-link">
#                     <div class="heading"><span>Телевизор</span></div>
#                     <div class="link"><span>Смотрим &laquo;Доисторическую планету&raquo;. Пятница: хацегоптерикс расправил крылья</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/05/27/tales-from-the-edge-of-the-self" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Анантасвами Анил &laquo;Ум тронулся, господа! Аномалии мозга глазами нейробиолога&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/05/26/prehistoric-planet-ice-worlds" class="container-link">
#                     <div class="heading"><span>Телевизор</span></div>
#                     <div class="link"><span>Смотрим &laquo;Доисторическую планету&raquo;. Четверг: гадрозавры на льду</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/05/25/rebel-cell" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Кэт Арни &laquo;Мятежная клетка: Рак, эволюция и новая наука о жизни&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2022/06/07/dig-for-science" class="container-link active">
#         	        	<div class="heading"><span>Эксперименты</span></div>
#             	    	<div class="link"><span>Кладмен &mdash; климатолог: как закапывать чайные пакетики, чтобы побыть своего рода ученым</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/09/oil-dispersant" data-id="33243" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2022/06/08/369d5f9b2050d2cbbf94987fd0715c28.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2022-06-09">11:40</span>
#                         </div>
#                         <h3>Эффективность дисперсантов для устранения разливов нефти снизилась за четыре дня</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/09/hic-plus-astrophys" data-id="33239" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-06-09">09:37</span>
#                 </div>
#
#                                     <h3>Комбинация астрофизических и лабораторных данных уточнила параметры нейтронных звезд</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/08/ovum-in-ovo" data-id="33237" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-06-08">вчера</span>
#                 </div>
#
#                                     <h3>В яйце динозавра нашли еще одно яйцо</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/08/hikikomori" data-id="33104" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-06-08">вчера</span>
#                 </div>
#
#                                     <h3>Хикикомори отличили по анализу крови</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/08/atomic-cooper-pairs" data-id="33227" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-06-08">вчера</span>
#                 </div>
#
#                                     <h3>Физики увидели атомные куперовские пары</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#                             <!-- ba3 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <низ страницы>-->
# <div id="adfox_154408219501673625"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push([{
#         ownerId: 248569,
#         containerId: 'adfox_154408219501673625',
#         params: {
#             pp: 'i',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['desktop', 'tablet'], {
#         tabletWidth: 830,
#         isAutoReloads: false
#     }]);
# })(window, 'adfoxAsyncParamsAdaptive');
# </script>
#
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/09/hic-plus-astrophys" data-id="33239" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/06/09/096001265d06668b2b19accd9c72980d.png)" class="ill"></div>
#
#
#
#                                     <h3>Комбинация астрофизических и лабораторных данных уточнила параметры нейтронных звезд</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/07/Functional-Connectivity-political-ideology" data-id="33211" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/06/06/e2826fb15da74c792ebcf33b73d356a5.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Функциональная МРТ помогла нейросети отличить либерала от консерватора</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/06/08/we-grow-mushrooms-at-home" data-id="33235" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/06/08/a478aab60031606472170e3b2c34d74b.gif)" class="ill"></div>
#
#
#
#                                     <h3>Англичане создали умную ферму для выращивания грибов на дому</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2022/06/02/0bb8c40b2e48e39599c5a1b5e6acde04.jpg" style=background-image:url(https://nplus1.ru/images/2022/06/06/67df5b6be1f15d9397d7e292c8e3a45e.jpg)>
#
#     <a href="/material/2022/06/03/deadly-food" data-id="33185" >
#         <div class="caption">
#                                                                                     <h3>Съедобное-несъедобное</h3>
#                     <p class="subtitle">Выберите блюдо и узнайте, кому оно годится в пищу (и почему)</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/medicine">Медицина</a>
#             </li>
#                                     <li>
#                 <a class="link-theme" href="/theme/bread-and-wine">Хлеб и вино</a>
#             </li>
#                     </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="pCE98f101eltMqRwuUCYS8Yq5TKIVsTfO3lZIz4q">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="pCE98f101eltMqRwuUCYS8Yq5TKIVsTfO3lZIz4q">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">9.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/06/boson-peak">Физики увидели поперечную природу бозонного пика в аморфных телах</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/09/hic-plus-astrophys">Комбинация астрофизических и лабораторных данных уточнила параметры нейтронных звезд</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/07/time-crystal-qubit">Физики превратили пару кристаллов времени в искусственный кубит</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/01/CaOH-in-MOT">Физики поймали в магнитооптическую ловушку многоатомные молекулы</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/08/atomic-cooper-pairs">Физики увидели атомные куперовские пары</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/08/Continuous-Bose-Einstein-condensation">Физики создали активную среду для непрерывного материальноволнового лазера</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/01/weak-phase-dif">Физики напрямую измерили разность фаз слабого взаимодействия у дважды странных барионов</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/02/Daya-Bay-2022">Коллаборация Daya Bay перевыполнила план по точности измерения смешивания антинейтрино</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/07/record-globus-m">Российские физики рекордно разогрели плазму в сферическом токамаке&nbsp;&laquo;Глобус-М2&raquo;</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/06/08/solar-flare">Солнечная вспышка ускорила почти все электроны в объеме высвобождения магнитной энергии</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/blog/2022/04/01/samotek">Авторам</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2022 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                                         </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                                         <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <script src="/js/tests/scopus/js/bundle.js"></script>
#
#
# <script>$(function(){$('html').removeClass('old-town-road')})</script>
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1650440205"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# # 5. Библиотека BeautifulSoup

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %% [markdown]
# ### Теперь мы можем извлекать данные из любой веб-страницы.
#
# Ранее мы уже получили содержимое страницы с помощью GET-запроса и сохранили информацию в переменной response , теперь создадим объект BeautifulSoup с именем page, указывая в качестве параметра html.parser.
#
# Для примера получим информацию o title (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ## ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ

# %% [markdown]
# ### Выполним поставленную ранее задачу: получить информацию о странице и извлечь заголовок статьи, опубликованной на этой странице, дату публикации, а также текст статьи.
#
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён в тег **<h1> … </h1> (заголовок первого уровня).**
#
# Тогда мы можем получить его текст с помощью метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
print(page.find('time').text)
# Out:
# 13:04
# 11 Окт. 2021

# %%
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.
def wiki_header(url):
    page=BeautifulSoup(requests.get(url).text,'html.parser')
    header=page.find('h1').text
    return header

# %%
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %%
wiki_header('https://ru.wikipedia.org/wiki/Python')
# Out:
# 'Python'

# %%
wiki_header('https://ru.wikipedia.org/wiki/%D0%A7%D0%B5%D0%BC%D0%BF%D0%B8%D0%BE%D0%BD%D0%B0%D1%82_%D0%BC%D0%B8%D1%80%D0%B0_%D0%BF%D0%BE_%D1%85%D0%BE%D0%BA%D0%BA%D0%B5%D1%8E_%D1%81_%D1%88%D0%B0%D0%B9%D0%B1%D0%BE%D0%B9_2022')
# Out:
# 'Чемпионат мира по хоккею с шайбой 2022'

# %% [markdown]
# ### НЕУНИКАЛЬНЫЕ ТЕГИ: ИЗВЛЕКАЕМ ТЕКСТ СТАТЬИ

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %%
print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article
## print(page.find('div', class_='js-mediator-article').text)
## print(page.find('div', class_='body js-mediator-article').text)
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.
#
#
#
#
#
#
#
#
#
# Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.
# Niklas Elmehed © Nobel Prize Outreach
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году предположила, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.
# Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.
# В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале «Тонкости молотка».
# В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале «Опыты на бедных». В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале «Почем знания для природы».
# Сергей Кузнецов

# %% [markdown]
# ## СБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ

# %% [markdown]
# ### Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег <a> … </a>. Попробуем использовать find():

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %% [markdown]
# ### Мы получили только одну ссылку, хотя на странице их явно больше.
#
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 939

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Open Programming Language', 'OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OpenQASM', 'OPS5', 'OptimJ', 'Orc', 'ORCA/Modula-2', 'Oriel']

# %%
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %% [markdown]
# ### Не все ссылки соответствуют названиям языков программирования — страница содержит также «служебные» ссылки, такие, например, как Jump to navigation (с англ. Перейти к навигации) или Alphabetical (с англ. По алфавиту):

# %% [markdown]
# ### Для обработки полученных данных и исключения «лишней» информации можно, например, использовать подходы, которые вы изучили в модуле PYTHON-14.

# %% [markdown]
# # 6. Работа с API

# %% [markdown]
# + API — это специальные разделы сайта, где информацию можно получать без разметки, а формат запросов и ответов зафиксирован. API созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.

# %% [markdown]
# ## КЛЮЧ АВТОРИЗАЦИИ

# %% [markdown]
# ### Для того чтобы начать работать с API, обычно необходимо получить сервисный ключ авторизации — токен.
#
# + Токен — это средство идентификации пользователя или отдельного сеанса работы в компьютерных сетях и приложениях. Различают программные и аппаратные токены.
# Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.

# %% [markdown]
# ## ЗАПРОС К API ИЗ КОДА

# %%
import requests # Импортируем модуль requests
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# ### Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода json(), после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# ### Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# ### Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
#
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# ### Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.

# %%
import requests # Импортируем модуль requests
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex, bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
response = requests.get(url, params=params).json()['response']
men = 0
women = 0
for el in response:
    if el['sex'] == 1:
        women +=1
    elif el['sex'] == 2:
        men +=1
    else:
        continue
    
print(round(women/(men+women),2))
# Out:
# 0.49

# %% [markdown]
# ## СБОР ИНФОРМАЦИИ ИЗ ГРУПП

# %% [markdown]
# ### В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# + ограничение на количество вызовов в единицу времени;
# + ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы [https://vk.com/vk](https://vk.com/vk) социальной сети ВКонтакте.
#
# Обратимся к [документации](https://vk.com/dev/groups), чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод [groups.getMembers](https://vk.com/dev/groups.getMembers).
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: [https://vk.com/vk](https://vk.com/vk). Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 12629277, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4236, 4262, 4282, 4326, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9399, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11531, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12821, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 13008, 13063, 13080, 13173, 13224, 13233, 13248, 13324, 13357, 13371, 13401, 134 ...

# %% [markdown]
# ### По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# ### Мы видим, что всего пользователей в группе больше 12 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %%
import requests # Импортируем модуль requests
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print(f'Выгружаю 5 пользователей с offset {(count, offset)}')   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset (5, 0)
# Выгружаю 5 пользователей с offset (5, 5)
# Выгружаю 5 пользователей с offset (5, 10)
# Выгружаю 5 пользователей с offset (5, 15)
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# ### Сравним списки, полученные двумя способами:

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# ### Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# ## ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ

# %% [markdown]
# + В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ## ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ

# %% [markdown]
# ### Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод [wall.get](https://vk.com/dev/wall.get). Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = 'd0825204d0825204d08252045ed0fea41edd082d0825204b22397749b4dfcf8b7ee8875' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 493,
#               'items': [{'comments': {'can_post': 1,
#                                       'count': 222,
#                                       'groups_can_post': True},
#                          'copy_history': [{'attachments': [{'photo': {'access_key': '9a97cb0d8f51c6e308',
#                                                                       'album_id': -7,
#                                                                       'date': 1654532449,
#                                                                       'id': 457240077,
#                                                                       'owner_id': 92933,
#                                                                       'post_id': 430,
#                                                                       'sizes': [{'height': 87,
#                                                                                  'type': 'm',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/rtqVScl7l0L5ZdCb1PUzb9_upr15tqfHGvmnr_7RtCVfBR5_UN3Bfh2hAgkgDhbvLyI4zMSQjb5-lAKOjzGIyK47.jpg?size=130x87&quality=96&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 87,
#                                                                                  'type': 'o',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/rtqVScl7l0L5ZdCb1PUzb9_upr15tqfHGvmnr_7RtCVfBR5_UN3Bfh2hAgkgDhbvLyI4zMSQjb5-lAKOjzGIyK47.jpg?size=130x87&quality=96&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 133,
#                                                                                  'type': 'p',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/xN1Uly0Bos_Lw9Xly58nd_jMWJxEzeezSzliP9xFOhKrJ3dUFGFcGQAPfKJuvbR3RmjYDlw_lDTkV6STOzlG0_b9.jpg?size=200x133&quality=96&type=album',
#                                                                                  'width': 200},
#                                                                                 {'height': 213,
#                                                                                  'type': 'q',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/Oj6wDOiac1JARMW108fCeuoZFIw11z2z6ua8V1pWsEIiGBU36X3WWyHUbmgK8DRILUzM36tzZ81OLx8LrmF9pxVu.jpg?size=320x213&quality=96&type=album',
#                                                                                  'width': 320},
#                                                                                 {'height': 340,
#                                                                                  'type': 'r',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/9yOX8391aTVFO1m-Mlx99HMmzQ9sHIXB5KJpmaecZM8jJIRYh2h0dkP1sUjZZa3kWWJvRF0X09HyBKk9eyIDtYrp.jpg?size=510x340&quality=96&type=album',
#                                                                                  'width': 510},
#                                                                                 {'height': 50,
#                                                                                  'type': 's',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/8ZNO68a-aDk0kVVRHWMMp2wIlhN4DNZ99bI9ynFDwOHkj4TqLP-sYXFyEhC6ZXrENDH2kkzGIE18vugqrHOKa0ID.jpg?size=75x50&quality=96&type=album',
#                                                                                  'width': 75},
#                                                                                 {'height': 403,
#                                                                                  'type': 'x',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/7ilSIXd4VNkAC9LVNkZI8M9RxdchW5wfaaGtXnuXBmMcweUS_HqWlMQ9DMD0Y5ykyteET2kHNRqoLq-Y8sFEeFGB.jpg?size=604x402&quality=96&type=album',
#                                                                                  'width': 604},
#                                                                                 {'height': 538,
#                                                                                  'type': 'y',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/jECtxgO3NzC9PFTJrkguXRNOKiSnKqSJ0K-4hbNJsaRQN6pxPmMs9Q51-H19m1EmgoKYhQ-sb-MnPP0YvRpcxgM5.jpg?size=807x538&quality=96&type=album',
#                                                                                  'width': 807},
#                                                                                 {'height': 853,
#                                                                                  'type': 'z',
#                                                                                  'url': 'https://sun7-13.userapi.com/s/v1/if2/uOXhHsKnaoi5vTmmgYeRBgc4uPUZ24h6CgTTOc-yd7OempCnIKpOt1vbv8PL-zoeQpOU1Mdfnc8dHYq0fT_wfdmG.jpg?size=1280x853&quality=96&type=album',
#                                                                                  'width': 1280}],
#                                                                       'text': ''},
#                                                             'type': 'photo'}],
#                                            'date': 1654532457,
#                                            'from_id': 92933,
#                                            'id': 430,
#                                            'owner_id': 92933,
#                                            'post_source': {'type': 'vk'},
#                                            'post_type': 'post',
#                                            'text': 'Сегодня ровно 10 лет моей '
#                                                    'работы в компании VK 🎉!\n'
#                                                    '\n'
#                                                    'Невероятным кажется путь, '
#                                                    'который мне удалось пройти '
#                                                    'за это время — от '
#                                                    'менеджера продукта и '
#                                                    'руководителя небольшой '
#                                                    'команды до СЕО ВКонтакте – '
#                                                    'социальной сети №1 в '
#                                                    'России. За это время мне '
#                                                    'посчастливилось '
#                                                    'поучаствовать в создании '
#                                                    'сразу нескольких ключевых '
#                                                    'продуктов экосистемы VK. \n'
#                                                    '\n'
#                                                    'Еще в 2013 году вместе с '
#                                                    'Командой Видео социальной '
#                                                    'сети Одноклассники мы '
#                                                    'создали одну из самых '
#                                                    'технологичных '
#                                                    'видеоплатформ в России. В '
#                                                    '2016 мы запустили первое '
#                                                    'мобильное стриминговое '
#                                                    'приложение OK Live с '
#                                                    'проприетарным протоколом '
#                                                    'адаптивного low-latecy '
#                                                    'стриминга, приложение OK '
#                                                    'Video на SmartTV. А в 2021 '
#                                                    'объединили все '
#                                                    'видеосервисы и технологии '
#                                                    'холдинга на платформе VK '
#                                                    'Видео, полностью '
#                                                    'перезапустив продукт, '
#                                                    'прошли путь до 2,45 '
#                                                    'миллиарда просмотров в '
#                                                    'сутки и 4 Тбит/с трафика. '
#                                                    'Это был настоящий вызов!\n'
#                                                    '\n'
#                                                    'В самый разгар пандемии в '
#                                                    'марте 2020 за 3 месяца (!) '
#                                                    'с нуля создали и запустили '
#                                                    'новый сервис коротких '
#                                                    'вертикальных видео Клипы '
#                                                    'ВКонтакте с уникальной '
#                                                    'AR-платформой и умной '
#                                                    'камерой. В этом году '
#                                                    'благодаря технологичным '
#                                                    'запускам и работе над '
#                                                    'алгоритмами добились '
#                                                    'рекордного роста суточных '
#                                                    'просмотров клипов на 20% — '
#                                                    'до 1 млрд. А месяц назад '
#                                                    'вместе с Командой и опять '
#                                                    'в рекордные сроки создали '
#                                                    'отдельное мобильное '
#                                                    'приложение VK Клипы, где '
#                                                    'есть еще больше '
#                                                    'возможностей для авторов '
#                                                    'контента.\n'
#                                                    '\n'
#                                                    'Развитие групповых '
#                                                    'видеозвонков мы начали в '
#                                                    '2018 году в ОК, затем в '
#                                                    '2020 добавили их '
#                                                    'ВКонтакте, а сейчас '
#                                                    'предлагаем пользователям '
#                                                    'воспользоваться для работы '
#                                                    'и общения отдельными '
#                                                    'мобильными приложениями VK '
#                                                    'Звонки и десктопным '
#                                                    'клиентом со всеми '
#                                                    'бизнес-функциями. Наша '
#                                                    'платформа видеоконференций '
#                                                    'стала единственной в мире '
#                                                    '(других подобных кейсов мы '
#                                                    'пока не знаем), которая '
#                                                    'способна объединить в '
#                                                    'звонке неограниченное '
#                                                    'количество участников. '
#                                                    'Добавили 4К демонстрацию '
#                                                    'экрана, ML-шумоподавление, '
#                                                    'умные фоны и десятки '
#                                                    'других удобных функций. \n'
#                                                    '\n'
#                                                    'Теперь про меня и '
#                                                    'ВКонтакте. Горжусь, что '
#                                                    'присоединилась к соцсети 3 '
#                                                    'года назад и стала частью '
#                                                    'большой дружной Команды. '
#                                                    'Нам удалось стать '
#                                                    'первооткрывателями в ряде '
#                                                    'технологических запусков и '
#                                                    'установить новые рекорды '
#                                                    'по коммерческим '
#                                                    'показателям и активности '
#                                                    'аудитории. В 2021 мы '
#                                                    'вырастили выручку '
#                                                    'ВКонтакте на рекордные '
#                                                    '21,9% до 27,9 млрд рублей '
#                                                    'и запустили рекордные за '
#                                                    'все время для соцсети 230 '
#                                                    'крупных технологических и '
#                                                    'продуктовых обновлений '
#                                                    '(это практически по одному '
#                                                    'запуску каждый рабочий '
#                                                    'день). \n'
#                                                    '\n'
#                                                    'В 2021 ВКонтакте стала '
#                                                    'лидирующей в России '
#                                                    'платформой по числу '
#                                                    'публикаций: в октябре 2021 '
#                                                    'года пользователи соцсети '
#                                                    'сделали свыше 408 млн '
#                                                    'постов — это в 3 раза '
#                                                    'больше, чем на любой '
#                                                    'другой площадке. А в 2022 '
#                                                    'установили рекорд '
#                                                    'ежемесячной активной '
#                                                    'аудитории — она впервые '
#                                                    'превысила 100 млн человек '
#                                                    'по всему миру. Cреди '
#                                                    'крупных запусков '
#                                                    'ВКонтакте, которыми мы '
#                                                    'гордимся в 2022 — новые '
#                                                    'отдельные мобильные '
#                                                    'приложения: VK Звонки, VK '
#                                                    'Клипы и VK Мессенджер. \n'
#                                                    '\n'
#                                                    'И на этом мы с Командой не '
#                                                    'собираемся '
#                                                    'останавливаться! \n'
#                                                    '\n'
#                                                    'Спасибо всем за '
#                                                    'поздравление! 10 лет — это '
#                                                    'только начало 🚀'}],
#                          'date': 1654534710,
#                          'from_id': -22822305,
#                          'hash': 'bbul6Z3PTQ5BbP7jwg',
#                          'id': 1302754,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1125,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 113, 'user_reposted': 0},
#                          'text': '',
#                          'views': {'count': 311401}},
#                         {'attachments': [{'photo': {'access_key': 'f429cb5d9aab1b6c62',
#                                                     'album_id': -7,
#                                                     'date': 1654183194,
#                                                     'id': 457331866,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/byWG8jhmxvjYgdBoi159sQ2uz1fomhgicq-dixB-uDAqADjbsCPVUbtIZ_qJYhesTGqH1iTEPKPzyZI1AuSakWnV.jpg?size=75x42&quality=95&type=album',
#                                                                'width': 75},
#                                                               {'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/6IcYLrqeIdljBlAQRxVamX2YiCMq8EbETyO_qa7m6Tqjy7zuP9aLlhKtIsjXIjR_h8vOAvzfeN21qniAW-iVnmcT.jpg?size=130x73&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 340,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/CGlsUj8qIQNt0H8c1TRlVyANjp9tgpXjUyxRWTtIuIuA_Ju71EIFsaMzcM3Y44TaTCldeAIOrUbZnUiw4qwBdXm5.jpg?size=604x340&quality=95&type=album',
#                                                                'width': 604},
#                                                               {'height': 454,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/SDP4u3Z6MVNRlc6SeNS__unU22MkvSdCEvfMlhqmbmrmahVT1Ej1NdKMhr9NzMsDmtVtRUWYbKqkFLfLqbqIkB33.jpg?size=807x454&quality=95&type=album',
#                                                                'width': 807},
#                                                               {'height': 720,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/yw15rYl8zWnLoPnIlYebezFaHofubGCmmGc7LfGxYK-Rxa9gT8sENCjcNxoCB4G3wcx8geU-bQN0vZEDEzXbXCVZ.jpg?size=1280x720&quality=95&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1080,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/TabMbPb0pvpcITPMwGfFal-UfU_2fJowIuNLM1scHvX9kTqNrDaQt4SBWCdtQBeqF1Kt6yvmCtQ6_F_6lFB3M8rs.jpg?size=1920x1080&quality=95&type=album',
#                                                                'width': 1920},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/BYG2dbIGL2qlvKIY3lwct3Dc5qNpQh5Qp1kYa8p_YMKNOgcZyjLCjRIKzPeo0s4K4DH5WCfdWDzO6Qjr0d3Ispda.jpg?size=130x87&quality=95&crop=153,0,1614,1080&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/rQJoMuKjwc8CeAnLvPMbXcrm87p10NV_FI97Dneer_mLxrlzJ4Hp6-KGMwTmgcaDFvJH4U7c2uTxR7vgEe5SXTFd.jpg?size=200x133&quality=95&crop=148,0,1624,1080&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/LmqLA3jZ8X8Dz6aq3l0oNjiAVUXqe8XV56wQNVGAcCcPg74WiYBFjeYt_9fponoral7GiZzBXOz0fq2cVy_CcyGE.jpg?size=320x213&quality=95&crop=148,0,1623,1080&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/qZw5_TQO5BsMLJNWpl_-wOzX3Y8DUDCp6rcI8pSR6L7ScQ0azA52pc2yACamlNosN0iqzTZbXe_MOgbnCjEQnuzZ.jpg?size=510x340&quality=95&crop=150,0,1620,1080&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 304,
#                                       'groups_can_post': True},
#                          'date': 1654181416,
#                          'edited': 1654183194,
#                          'from_id': -22822305,
#                          'hash': '7X_yTzDRONN_5CgGzA',
#                          'id': 1302148,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 733,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 208, 'user_reposted': 0},
#                          'text': 'Что нового ВКонтакте по итогам мая — '
#                                  'рассказываем:\n'
#                                  '\n'
#                                  '✅ Запустили отдельный '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=vk-messendzher|VK '
#                                  'Мессенджер]: в нём есть всё для общения и '
#                                  'свои фишки. Можно не показывать, что вы в '
#                                  'сети, и создавать чаты с исчезающей '
#                                  'перепиской.\n'
#                                  '\n'
#                                  '✅ Ещё одно новое приложение — '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=vk-klipy|VK '
#                                  'Клипы]. Здесь прокачали инструменты для '
#                                  'авторов: ускорили камеру, добавили всё для '
#                                  'монтажа и обработки. Можно снимать клипы до '
#                                  '3 минут, пробовать эксклюзивные эффекты и '
#                                  'маски.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=servisy|Сервис '
#                                  '«Найди меня»] поможет разыскать знакомых, с '
#                                  'которыми прервалась связь. Поиск идёт по 100 '
#                                  'миллионам профилей ВКонтакте и в '
#                                  'Одноклассниках.\n'
#                                  '\n'
#                                  '✅ В '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=kommentarii|клипах] '
#                                  'негативные комментарии автоматически '
#                                  'скрываются — читать их или нет, решаете вы.\n'
#                                  '\n'
#                                  '✅ Годовую подписку '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=vk-donut|VK '
#                                  'Donut] теперь можно оформить с мобильного.\n'
#                                  '\n'
#                                  '✅ Смотреть видео будет комфортнее даже при '
#                                  'слабом интернете. Внедрили новый '
#                                  'интернет-протокол: с ним ролики быстрее '
#                                  'стартуют, а пауз и задержек меньше. Ещё в '
#                                  '[https://vk.com/blog/digest-obnovleniy-may?anchor=vk-video|VK '
#                                  'Видео] готовится премьера: первый сериал по '
#                                  'сценарию от нейросети.\n'
#                                  '\n'
#                                  'Подробности уже в дайджесте 👇\n'
#                                  'vk.cc/ce4BGQ',
#                          'views': {'count': 231098}},
#                         {'attachments': [{'photo': {'access_key': 'b27d4abb1ea83f66c6',
#                                                     'album_id': -7,
#                                                     'date': 1653544885,
#                                                     'id': 457331766,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1301322,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/thTcAi8K9n7R7akaV6AUcQDyomtHrSeYfOjc057T3wv7tLstCVckaXCmnN92FNNdifYiUsqPREdbJlFX87jZesEA.jpg?size=75x75&quality=95&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/URCRJWx5NP1SMsgPg0RRVIeDHo7ojKTTUsKb6niC7w3lDAtpxVXk_O1bSicYFBpXL4s2lQXIY7Gl39zPb40VmtK9.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/X6wuW1cW-RhAkoN7D_QD3BJ4ACmyT0DNz-cu63wectpHzpFPg7dlmKSndg65FvwbwTzto6j14S4N3JFIw5R60aFs.jpg?size=604x604&quality=95&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/8ldr6lNCECHZ7K8IdPEbPtLbJCpCdOcOZXibs4UmOc8QJZtCRdST46yfqW9F4Y3Spv48SrjuXSVtcDHxbsjXW4L0.jpg?size=807x807&quality=95&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/qxajwtxt5DAOVxX4X4uMC1U1VLFKKsbUTVVJ339PV9Jn--5Yu3_iYpQxscZeVmFJlDKheqZAyLxuvlwtp8NY09dL.jpg?size=1080x1080&quality=95&type=album',
#                                                                'width': 1080},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/URCRJWx5NP1SMsgPg0RRVIeDHo7ojKTTUsKb6niC7w3lDAtpxVXk_O1bSicYFBpXL4s2lQXIY7Gl39zPb40VmtK9.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/3iEfza_resj6-6ejDRAFErUPBLGq6BHMBl0wMYkuwKnllQ_o9TdkEc3pPWJLXBh6fOnlYSbyeMcdwiwf6dQK_eWE.jpg?size=200x200&quality=95&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/aFJf0jaK_IeuBFwhfN5GLpvq4EH8nJJsiFvuCm2Ecr7TTc-bXle9S_dn1U66IGfzbKby0F4OhZ0fuSJ5KZjP6aIK.jpg?size=320x320&quality=95&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-8.userapi.com/s/v1/ig2/gkR1gj378wZcenIHScau2fjMj647BDi4idOK4Dv3NIhkl7PeXkraeS-AE8fQGL_3aVELOBzc7XP1NPpcl54x9Fuw.jpg?size=510x510&quality=95&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 298,
#                                       'groups_can_post': True},
#                          'date': 1653545902,
#                          'edited': 1653552755,
#                          'from_id': -22822305,
#                          'hash': 'zFmSnf22FSQS3ZcHbg',
#                          'id': 1301322,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 973,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 405, 'user_reposted': 0},
#                          'text': '[club86529522|VK Fest] расширяется — 23 и 24 '
#                                  'июля фестиваль пройдёт сразу в трёх городах: '
#                                  'в Москве, Санкт-Петербурге и Сириусе '
#                                  '(Сочи).\n'
#                                  '\n'
#                                  'В Санкт-Петербурге и Москве посетителей ждут '
#                                  'два насыщенных дня. На сцены выйдут '
#                                  '[club18022279|FEDUK], [club32955254|Мари '
#                                  'Краймбрери], [club143170619|NILETTO], '
#                                  '[club26607605|GAYAZOV$ BROTHER$], '
#                                  '[club109964404|The Hatters] и другие '
#                                  'популярные артисты. Многие из них успеют '
#                                  'выступить сразу в двух городах. Кроме музыки '
#                                  'на фестивале будет немало интересного — '
#                                  'выступления блогеров и стендаперов, '
#                                  'лекторий, а также видеоигры, мастер-классы, '
#                                  'спортивные турниры и другие развлечения. '
#                                  'Билеты можно купить здесь: vk.cc/tickets.\n'
#                                  '\n'
#                                  'В Сириусе (Сочи) в ночь с субботы на '
#                                  'воскресенье в центре Олимпийского парка '
#                                  'выступят [club27112805|МакSим], '
#                                  '[id547633957|Леонид Агутин], '
#                                  '[club41888802|Cream soda], '
#                                  "[club174066348|Ramil'], [club2703292|DJ "
#                                  'SMASH] и другие звёзды. Вход свободный!\n'
#                                  '\n'
#                                  'Все три города объединит диджитал-мост — '
#                                  'большая трансляция с ведущими '
#                                  '[id1701766|Владимиром Маркони], '
#                                  '[club59085032|Аллой Михеевой], '
#                                  '[id2670899|Идой Галич] и другими '
#                                  'знаменитостями. Посмотреть её можно будет в '
#                                  '[club86529522|сообществе фестиваля].\n'
#                                  '\n'
#                                  'Всю информацию про билеты, аккредитацию и '
#                                  'полный лайнап также опубликуем в '
#                                  '[club86529522|паблике VK Fest]. '
#                                  'Подписывайтесь и готовьтесь к жаркому лету!',
#                          'views': {'count': 322770}},
#                         {'attachments': [{'photo': {'access_key': '5ee2cb1543cccabcc5',
#                                                     'album_id': -7,
#                                                     'date': 1652775276,
#                                                     'id': 457331640,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1300134,
#                                                     'sizes': [{'height': 65,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/NREzzXksEjeyBob291jozjf5XCv_8czWMrdB6KwV7rUI5QMAbUa5L5owbzpfRikFf57LKtuG3s1D-j1oTy8-Nfn4.jpg?size=75x65&quality=95&type=album',
#                                                                'width': 75},
#                                                               {'height': 112,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/Z_CFp4i0wEDLu1y2DWeQg63-q-OZQwRTszraaZyDEpjKwW0T4M0C83f8ZpybYhs1md279CGJHpYtudIjtehq9Jn0.jpg?size=130x112&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 520,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/u_GPxsm3yE6P3RoUPZ3U_N7gS7QBMuJmUDXwjUvV97YICtg5BdmeTI7iz9lx8lUZLWEnIHBPoVU4HqX87XEMZ4fQ.jpg?size=604x520&quality=95&type=album',
#                                                                'width': 604},
#                                                               {'height': 695,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/MR-AL-7RSfK9n9VeEajIe-RzFrBFSYGGUI7MeTRn2bDezY_bQ1WNrB3O2B7v45jbrDyzjkhxyz4jJ6Yr7FIyYYkW.jpg?size=807x695&quality=95&type=album',
#                                                                'width': 807},
#                                                               {'height': 1102,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/_-6ZUVIGCtvuDGKhXaH3NoJWrD7wX5rgB2qirgkKZePnS_GZgPP1HJuvXbs2Sueo_IqgBkS7aPxMeJJSxlTxnR_Q.jpg?size=1280x1102&quality=95&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1894,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/Cu8_zhbSiIf-RUqUog7T67160On0UcwtIULJ1wM31atsFYdzAS-TEK_ISFjyq5c_4-xG-DVgToi_bvNg3B94xMyF.jpg?size=2200x1894&quality=95&type=album',
#                                                                'width': 2200},
#                                                               {'height': 112,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/Z_CFp4i0wEDLu1y2DWeQg63-q-OZQwRTszraaZyDEpjKwW0T4M0C83f8ZpybYhs1md279CGJHpYtudIjtehq9Jn0.jpg?size=130x112&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 172,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/w09w5mW4lGmwM8FotF-ko6Us6rjnT-6F0OlcK-Px3c2ZcPq7QpllAv_yZ6P6nJoQZ_GyyVnfzfg4YbyPHa_rQ5eg.jpg?size=200x172&quality=95&type=album',
#                                                                'width': 200},
#                                                               {'height': 275,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/4daUODl6byXUC6Y3r9HnNz1h_2_jHx3W-uUhy3_-DZARZVZcUqyC0OZpZFdmkS8_Z2Iwof2BpgAbjm5ldR0ZplF-.jpg?size=320x275&quality=95&type=album',
#                                                                'width': 320},
#                                                               {'height': 439,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-6.userapi.com/s/v1/ig2/wmRykx3rj1BMzc34NBrFirtHV6dPFFAh8KFSokq0Bmk2HjJF7lf_2Uxrp7nb3f3Qr0KU_jH9OKx2nCr2SSNEJh9S.jpg?size=510x439&quality=95&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 581,
#                                       'groups_can_post': True},
#                          'date': 1652775512,
#                          'edited': 1652864731,
#                          'from_id': -22822305,
#                          'hash': 'nN_VN4Ygo9tMV67-GA',
#                          'id': 1300134,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1477,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 941, 'user_reposted': 0},
#                          'text': 'Представляем VK Мессенджер: он уже доступен '
#                                  'в App Store (vk.cc/cdDmmV) и Google Play '
#                                  '(vk.cc/8PGS7S). В лёгком и быстром мобильном '
#                                  'приложении есть всё для общения. \n'
#                                  '\n'
#                                  '✔ Будьте на связи с друзьями из ВКонтакте и '
#                                  'телефонной книги. \n'
#                                  'Обменивайтесь стикерами, музыкой, фото, '
#                                  'видео, файлами, и геотегами. Чаты можно '
#                                  'оформить яркими фонами под настроение.\n'
#                                  '\n'
#                                  '✔ Звоните с аудио и видео без ограничений. \n'
#                                  'А у голосовых сообщений есть расшифровка — '
#                                  'чтобы читать, когда неудобно слушать.\n'
#                                  '\n'
#                                  '✔ Отправляйте исчезающие сообщения.\n'
#                                  'Например, когда хочется пошутить в серьёзной '
#                                  'беседе, не засоряя её. А для быстрых '
#                                  'вопросов можно создавать фантомные чаты — в '
#                                  'них переписка очистится через некоторое '
#                                  'время.\n'
#                                  '\n'
#                                  'И это далеко не все возможности нового '
#                                  'приложения. Попробуйте сами: vk.me/app.',
#                          'views': {'count': 436487}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '65915a58f0034c34ea',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 16,
#                                                     'date': 1652252556,
#                                                     'description': 'Сконцентрируйтесь '
#                                                                    'на главном '
#                                                                    '— снимайте '
#                                                                    'короткие '
#                                                                    'видео в '
#                                                                    'приложении '
#                                                                    'VK Клипы и '
#                                                                    'становитесь '
#                                                                    'популярнее: '
#                                                                    'https://vk.cc/cdpXaB',
#                                                     'duration': 18,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2311301499521&idx=0&type=39&tkn=xBj4ieQSogq8ZMDlR7kbfjHF4_I',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2311301499521&idx=0&type=39&tkn=xBj4ieQSogq8ZMDlR7kbfjHF4_I&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2311301499521&idx=0&type=39&tkn=xBj4ieQSogq8ZMDlR7kbfjHF4_I&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2311301499521&idx=0&type=39&tkn=xBj4ieQSogq8ZMDlR7kbfjHF4_I&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2311301499521&idx=0&type=39&tkn=xBj4ieQSogq8ZMDlR7kbfjHF4_I&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239869,
#                                                     'owner_id': -194351072,
#                                                     'photo_1280': 'https://sun7-13.userapi.com/impf/yIDwhj5miv8l8_xFa4T3KdCOvn_Mcacjz_JMTg/B8LpgnN0bHc.jpg?size=1280x720&quality=96&sign=3d1318229d0e8d9e20c2f94e7a1fc0af&c_uniq_tag=phvPrKMphKFH-dim3VxGDHt_58INNwn9DAqSMC43PiA&type=video_thumb',
#                                                     'photo_130': 'https://sun7-13.userapi.com/impf/yIDwhj5miv8l8_xFa4T3KdCOvn_Mcacjz_JMTg/B8LpgnN0bHc.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=29ef9e92306866a7d6679009e6f879d8&c_uniq_tag=wOVuC_gDjmd_zaM9NdkOVrMfz1XdCcjulG5Bi4CULZc&type=video_thumb',
#                                                     'photo_320': 'https://sun7-13.userapi.com/impf/yIDwhj5miv8l8_xFa4T3KdCOvn_Mcacjz_JMTg/B8LpgnN0bHc.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=fb12c9356c382b88c145186a45cca5e8&c_uniq_tag=5wQBJPoD-Csm-Lgy_DdGuU_vOiP5_c7TTn1_ymWVQhM&type=video_thumb',
#                                                     'photo_800': 'https://sun7-13.userapi.com/impf/yIDwhj5miv8l8_xFa4T3KdCOvn_Mcacjz_JMTg/B8LpgnN0bHc.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=beb46989bcb34bd198827dcecc0049f7&c_uniq_tag=LDn6u7_y4b2_EEESi2tA03u6V1tLB3Mvbmw52nG1-dw&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'VK Клипы. Место '
#                                                              'встречи талантов',
#                                                     'track_code': 'video_f0572949wwAfi5T8ER3BNMJ-jyjxTp-2H6ja9WQwS85s3Z9Navz5JgCJnf19GcI9zHniJMR4rYUmkOzMYEcqogDd',
#                                                     'views': 836514,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 295,
#                                       'groups_can_post': True},
#                          'date': 1652363220,
#                          'from_id': -22822305,
#                          'hash': '5mYEKfIjEyv4EO2PMw',
#                          'id': 1299528,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1057,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
# ...
#                                  'также верифицированных сообществ медиа. '
#                                  'Каждую неделю мини-приложение и ленту '
#                                  'посещают более 20 миллионов пользователей. \n'
#                                  '\n'
#                                  'Мы делаем всё возможное, чтобы защитить '
#                                  'людей от неоправданной паники из-за фейковых '
#                                  'новостей, и при этом создаём пространство '
#                                  'для обсуждений и выражения личной позиции.',
#                          'views': {'count': 1278106}},
#                         {'attachments': [{'photo': {'access_key': '7c29861d3ecd8b4202',
#                                                     'album_id': -7,
#                                                     'date': 1586521750,
#                                                     'id': 457309386,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1070698,
#                                                     'sizes': [{'height': 93,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/5x8woBOi9WbJTuNCHDmqWl-i_HWAKBY3WA9VRljYbZI5DjU2hKpuDAp7uWe85ZXfJZj5SO64BzbfwKt1_t_epFFu.jpg?size=130x93&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 93,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/5x8woBOi9WbJTuNCHDmqWl-i_HWAKBY3WA9VRljYbZI5DjU2hKpuDAp7uWe85ZXfJZj5SO64BzbfwKt1_t_epFFu.jpg?size=130x93&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 143,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/z0yRh8CaymrYeYnbG2VJjVWqAGyHKgM0NZesoXULPrjqma2CWDjTR_bk7abuaBlbW7t5BD5ZIZD5cXBpg7lz4eDD.jpg?size=200x143&quality=96&type=album',
#                                                                'width': 200},
#                                                               {'height': 229,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/m8-CU_KRWVUzUF9y2gJcbYmohcbNmzuJG3bkQ-YY0F9G_0Rrq1HMolRaKXAUeNghh_hde3x9eR3-bFP_JdH-S2LB.jpg?size=320x229&quality=96&type=album',
#                                                                'width': 320},
#                                                               {'height': 364,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/1G3PLEdiPIIloBQIedSMxPoNCgmgwdxlMSUDtCuBzCHtVIys-SsXEBPr9PfVlh_lirlXDsD6wXlYyR-pAK-A0pWR.jpg?size=510x364&quality=96&type=album',
#                                                                'width': 510},
#                                                               {'height': 54,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/ZyeogT3Gik3AcaZYnqSJsfW1f0OJ0UuVPrwhu_yLNhQf1bDH0sjRgUN86vXPI0DPEOzokIloVlhJNmKddJ3AdxRI.jpg?size=75x54&quality=96&type=album',
#                                                                'width': 75},
#                                                               {'height': 1786,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/U7TTFc9MURjzB6FgassnOCkpNo40LHavMcyNHPdjgnH6b87ET_UitMu_rD0dYayIJ-hWtm6daQGsjLrzv_u9rCld.jpg?size=2500x1786&quality=96&type=album',
#                                                                'width': 2500},
#                                                               {'height': 431,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/M0BWcsj5jb2QtJGH9UtPUFJKc5kOVSeTElKqu_pT7-emlSFCfdo1FffCI-g3WUqwvVfY162jLayNAmcJBH2w8Wb2.jpg?size=604x431&quality=96&type=album',
#                                                                'width': 604},
#                                                               {'height': 576,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/a6z68yUL9Xe42diT6JSfxZkq4LivDC-s-bv2gX2otnIhky7b7dicZm3vZ5W953Kz9SeMrsM7AI4GbXDAhFEW94-O.jpg?size=807x577&quality=96&type=album',
#                                                                'width': 807},
#                                                               {'height': 914,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-9.userapi.com/s/v1/ig2/XBVd8Q-KRBdyAeUCnoYL6v9V6-CKSAwUqGM86pTctJRqnKieHSduFXhn7hBm-Ii_jwNB4Sx2ug5-Zbp6gL7cBSG3.jpg?size=1280x914&quality=96&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 652,
#                                       'groups_can_post': True},
#                          'date': 1586521801,
#                          'from_id': -22822305,
#                          'hash': 'WUG6nfpGO4HtB-sirQ',
#                          'id': 1070698,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2758,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 164, 'user_reposted': 0},
#                          'text': 'На первый взгляд кажется, что самоизоляция '
#                                  'нас ограничивает, но на деле — открывает '
#                                  'новые возможности. Вся жизнь перетекла в '
#                                  'онлайн: теперь время, которое раньше тратили '
#                                  'на дорогу до учёбы или работы, можно '
#                                  'провести за просмотром спектаклей, '
#                                  'концертов, игровых стримов и познавательных '
#                                  'видео. \n'
#                                  '\n'
#                                  'Чтобы вы легко находили самое интересное и '
#                                  'планировали досуг, мы сделали '
#                                  'мини-приложение '
#                                  '[https://vk.com/stayhome|Дома посмотрю]. Это '
#                                  'афиша онлайн-мероприятий с тематическими '
#                                  'подборками — о музыке, играх, культуре, '
#                                  'спорте и образовании. Выберите категорию, к '
#                                  'которой лежит душа, — и увидите все события. '
#                                  'Расписание регулярно обновляется.\n'
#                                  '\n'
#                                  'Проводите время с пользой и не лишайте себя '
#                                  'новых впечатлений!',
#                          'views': {'count': 1084252}},
#                         {'attachments': [{'photo': {'access_key': 'ab907244bc360d6d14',
#                                                     'album_id': -7,
#                                                     'date': 1584713329,
#                                                     'id': 457308458,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1061966,
#                                                     'sizes': [{'height': 90,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/OptQRWkSX8R9O5h6r5wcy5R0vWxc4cYxoHancptfFT1v3AJ6qnTJH3mDUVnFY5YXP4y_NzityrIJuVY98M6yAVNs.jpg?size=130x90&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 90,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/OptQRWkSX8R9O5h6r5wcy5R0vWxc4cYxoHancptfFT1v3AJ6qnTJH3mDUVnFY5YXP4y_NzityrIJuVY98M6yAVNs.jpg?size=130x90&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 139,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/cKPQqfiGs1ZybQSi09jRejLIXGR-PLNszbnb4ltJOULdvDnk-9TNDy9osqzD3AlgD8AY85pg9jcAQEaNTXFBKU4p.jpg?size=200x139&quality=96&type=album',
#                                                                'width': 200},
#                                                               {'height': 223,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/VwhBZkTJBW7f2udUCRXcK8tqLCSlIQgnbz4GmXicbaWK3EIg3GchJEq2FMfhXS5gyIcvBHOy06F4Ig8XWcglezyk.jpg?size=320x223&quality=96&type=album',
#                                                                'width': 320},
#                                                               {'height': 355,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/mN5rEzPJ1oDjrWxM6XILqzcMdtsh6wHVuOECMTNcDycrOVnwGMdu0-hq4yJ9L9IWUDqFADA3MjJ93Z-GAqejBOsV.jpg?size=510x355&quality=96&type=album',
#                                                                'width': 510},
#                                                               {'height': 52,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/vrMsE6t0SLrvMeZRzGzo1_gM2i7yinRo0FRarKko9IuDP7mIb6an-1qTcDsGKE7iMA_-99gA6jobOvjBxSW0DEIe.jpg?size=75x52&quality=96&type=album',
#                                                                'width': 75},
#                                                               {'height': 420,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/inRxilN64FY3N0BhVPBumbq7IBUzkucCYioBS7Roet_gU7RFjCG9AF6jor4AQqbnDGVo5lKTKjhTFa15k2RQdYbU.jpg?size=604x420&quality=96&type=album',
#                                                                'width': 604},
#                                                               {'height': 561,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/teMXWUXnSNJHxvSPoo6OQCPThCfSBKJKoYcS01GdyOoUi_N8rlSVS_CV2OlsyF6q7J1TG0wF6EHjePX692YI15K3.jpg?size=807x561&quality=96&type=album',
#                                                                'width': 807},
#                                                               {'height': 800,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-14.userapi.com/s/v1/ig2/jLGQhtSwP0kVnzcPBdfyS3PprcDvhxCVS6zRJvuAamy8QXcea3JxVOt9m-h48Or8F5q8evj-jMvRkGkX2zKHotRv.jpg?size=1150x800&quality=96&type=album',
#                                                                'width': 1150}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2273,
#                                       'groups_can_post': True},
#                          'date': 1584713515,
#                          'from_id': -22822305,
#                          'hash': 'dyS6kRTOrEsUhiVa9Q',
#                          'id': 1061966,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4139,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 249, 'user_reposted': 0},
#                          'text': 'Запускаем единый центр информации по '
#                                  'коронавирусу. В одном мини-приложении вы '
#                                  'найдёте всю актуальную и достоверную '
#                                  'информацию о '
#                                  '[https://vk.com/covid19|COVID-19].\n'
#                                  '\n'
#                                  'Как защитить себя от коронавируса, какие у '
#                                  'него симптомы и куда звонить, если вы их у '
#                                  'себя заметили, — все ответы собраны здесь. '
#                                  'Вы и так всё знаете? Пройдите тест и '
#                                  'проверьте, не ошибаетесь ли. Результатом '
#                                  'сможете поделиться с друзьями. Также в '
#                                  'мини-приложении легко следить за новостями о '
#                                  'пандемии — они собираются из проверенных '
#                                  'источников.\n'
#                                  '\n'
#                                  'Чтобы не скучать дома и легко преодолевать '
#                                  'бытовые трудности, загляните в блок «Как '
#                                  'провести карантин». Подборки игр, подкастов '
#                                  'и образовательных проектов, сервисы для '
#                                  'заказа еды, поиска работы и самостоятельных '
#                                  'тренировок — используйте время с пользой. \n'
#                                  '\n'
#                                  'Мини-приложение COVID-19 открывается при '
#                                  'нажатии на виджет во второй вкладке '
#                                  'мобильного приложения VK, а также по прямой '
#                                  'ссылке: vk.com/covid19',
#                          'views': {'count': 1413505}}]}}

# %% [markdown]
# ### Анализируя ответ, понимаем, что по ключу count можно найти общее количество сообщений в новостной ленте, а по ключу items — сами сообщения.
#
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1302754,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1654534710,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': '',
#  'copy_history': [{'id': 430,
#    'owner_id': 92933,
#    'from_id': 92933,
#    'date': 1654532457,
#    'post_type': 'post',
#    'text': 'Сегодня ровно 10 лет моей работы в компании VK 🎉!\n\nНевероятным кажется путь, который мне удалось пройти за это время — от менеджера продукта и руководителя небольшой команды до СЕО ВКонтакте – социальной сети №1 в России. За это время мне посчастливилось поучаствовать в создании сразу нескольких ключевых продуктов экосистемы VK. \n\nЕще в 2013 году вместе с Командой Видео социальной сети Одноклассники мы создали одну из самых технологичных видеоплатформ в России. В 2016 мы запустили первое мобильное стриминговое приложение OK Live с проприетарным протоколом адаптивного low-latecy стриминга, приложение OK Video на SmartTV. А в 2021 объединили все видеосервисы и технологии холдинга на платформе VK Видео, полностью перезапустив продукт, прошли путь до 2,45 миллиарда просмотров в сутки и 4 Тбит/с трафика. Это был настоящий вызов!\n\nВ самый разгар пандемии в марте 2020 за 3 месяца (!) с нуля создали и запустили новый сервис коротких вертикальных видео Клипы ВКонтакте с уникальной AR-платформой и умной камерой. В этом году благодаря технологичным запускам и работе над алгоритмами добились рекордного роста суточных просмотров клипов на 20% — до 1 млрд. А месяц назад вместе с Командой и опять в рекордные сроки создали отдельное мобильное приложение VK Клипы, где есть еще больше возможностей для авторов контента.\n\nРазвитие групповых видеозвонков мы начали в 2018 году в ОК, затем в 2020 добавили их ВКонтакте, а сейчас предлагаем пользователям воспользоваться для работы и общения отдельными мобильными приложениями VK Звонки и десктопным клиентом со всеми бизнес-функциями. Наша платформа видеоконференций стала единственной в мире (других подобных кейсов мы пока не знаем), которая способна объединить в звонке неограниченное количество участников. Добавили 4К демонстрацию экрана, ML-шумоподавление, умные фоны и десятки других удобных функций. \n\nТеперь про меня и ВКонтакте. Горжусь, что присоединилась к соцсети 3 года назад и стала частью большой дружной Команды. Нам удалось стать первооткрывателями в ряде технологических запусков и установить новые рекорды по коммерческим показателям и активности аудитории. В 2021 мы вырастили выручку ВКонтакте на рекордные 21,9% до 27,9 млрд рублей и запустили рекордные за все время для соцсети 230 крупных технологических и продуктовых обновлений (это практически по одному запуску каждый рабочий день). \n\nВ 2021 ВКонтакте стала лидирующей в России платформой по числу публикаций: в октябре 2021 года пользователи соцсети сделали свыше 408 млн постов — это в 3 раза больше, чем на любой другой площадке. А в 2022 установили рекорд ежемесячной активной аудитории — она впервые превысила 100 млн человек по всему миру. Cреди крупных запусков ВКонтакте, которыми мы гордимся в 2022 — новые отдельные мобильные приложения: VK Звонки, VK Клипы и VK Мессенджер. \n\nИ на этом мы с Командой не собираемся останавливаться! \n\nСпасибо всем за поздравление! 10 лет — это только начало 🚀',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1654532449,
#       'id': 457240077,
#       'owner_id': 92933,
#       'access_key': '9a97cb0d8f51c6e308',
#       'post_id': 430,
#       'sizes': [{'height': 87,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/rtqVScl7l0L5ZdCb1PUzb9_upr15tqfHGvmnr_7RtCVfBR5_UN3Bfh2hAgkgDhbvLyI4zMSQjb5-lAKOjzGIyK47.jpg?size=130x87&quality=96&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 87,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/rtqVScl7l0L5ZdCb1PUzb9_upr15tqfHGvmnr_7RtCVfBR5_UN3Bfh2hAgkgDhbvLyI4zMSQjb5-lAKOjzGIyK47.jpg?size=130x87&quality=96&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/xN1Uly0Bos_Lw9Xly58nd_jMWJxEzeezSzliP9xFOhKrJ3dUFGFcGQAPfKJuvbR3RmjYDlw_lDTkV6STOzlG0_b9.jpg?size=200x133&quality=96&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/Oj6wDOiac1JARMW108fCeuoZFIw11z2z6ua8V1pWsEIiGBU36X3WWyHUbmgK8DRILUzM36tzZ81OLx8LrmF9pxVu.jpg?size=320x213&quality=96&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/9yOX8391aTVFO1m-Mlx99HMmzQ9sHIXB5KJpmaecZM8jJIRYh2h0dkP1sUjZZa3kWWJvRF0X09HyBKk9eyIDtYrp.jpg?size=510x340&quality=96&type=album',
#         'type': 'r',
#         'width': 510},
#        {'height': 50,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/8ZNO68a-aDk0kVVRHWMMp2wIlhN4DNZ99bI9ynFDwOHkj4TqLP-sYXFyEhC6ZXrENDH2kkzGIE18vugqrHOKa0ID.jpg?size=75x50&quality=96&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 403,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/7ilSIXd4VNkAC9LVNkZI8M9RxdchW5wfaaGtXnuXBmMcweUS_HqWlMQ9DMD0Y5ykyteET2kHNRqoLq-Y8sFEeFGB.jpg?size=604x402&quality=96&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 538,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/jECtxgO3NzC9PFTJrkguXRNOKiSnKqSJ0K-4hbNJsaRQN6pxPmMs9Q51-H19m1EmgoKYhQ-sb-MnPP0YvRpcxgM5.jpg?size=807x538&quality=96&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 853,
#         'url': 'https://sun7-13.userapi.com/s/v1/if2/uOXhHsKnaoi5vTmmgYeRBgc4uPUZ24h6CgTTOc-yd7OempCnIKpOt1vbv8PL-zoeQpOU1Mdfnc8dHYq0fT_wfdmG.jpg?size=1280x853&quality=96&type=album',
#         'type': 'z',
#         'width': 1280}],
#       'text': ''}}],
#    'post_source': {'type': 'vk'}}],
#  'post_source': {'platform': 'iphone', 'type': 'api'},
#  'comments': {'can_post': 1, 'count': 222, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 1125, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 113, 'user_reposted': 0},
#  'views': {'count': 311401},
#  'hash': 'bbul6Z3PTQ5BbP7jwg'}

# %% [markdown]
# ### В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.

# %% [markdown]
# ### Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'[club86529522|VK Fest] расширя': [298, 973, 405, 1653545902],
#  '[vk.com/press/q1-2022-results|': [627, 2038, 401, 1651223357],
#  'В VK Видео — обновление для лю': [249, 1109, 273, 1649929834],
#  'В конце марта мы запустили мас': [345, 1155, 455, 1651043800],
#  'За первый квартал 2022 года ав': [295, 1057, 260, 1652363220],
#  'Подводим итоги апреля:\n \n☑ В [': [479, 1058, 196, 1651827295],
#  'Представляем VK Мессенджер: он': [581, 1477, 941, 1652775512],
#  'Представляем мобильное приложе': [506, 1202, 370, 1650036838],
#  'Тёмная тема ВКонтакте теперь н': [853, 3266, 1970, 1650901064],
#  'Что нового ВКонтакте по итогам': [304, 733, 208, 1654181416]}

# %% [markdown]
# ### Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: всё, что можно делать вручную через браузер, доступно и в API.

# %% [markdown]
# # ДРУГИЕ API
#
# Вы познакомились с интерфейсами прикладного программирования — API (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:
#
# + [Google Maps API](https://developers.google.com/maps/)
# + [YouTube API](https://developers.google.com/youtube/)
# + [Twitter API](https://dev.twitter.com/overview/documentation)
# + [Facebook API](https://developers.facebook.com/docs/)
# Информацию о сторонних API можно найти в [каталоге Web API](https://www.programmableweb.com/category/all/apis). Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.

# %% [markdown]
# # 7. Как настроить регулярную выгрузку данных

# %% [markdown]
# ## СКРИПТЫ

# %% [markdown]
# ### Как уже говорилось, скриптом принято называть небольшую компьютерную программу, которая автоматизирует выполнение некоторой задачи. Программы, которые мы создаём на языке Python, также являются скриптами.
#
# Скрипт можно использовать разными способами:
#
# + Если вам нужно выполнить код один раз или выполнять его очень редко (от случая к случаю), вы можете запустить скрипт вручную из командной строки.
# + Если вы, например, написали на Python серверную часть веб-сайта и хотите, чтобы ваш код мог в любое время обрабатывать запросы, вы захотите запустить его как фоновый процесс.
#
# А что делать, если вам нужно, чтобы ваш скрипт запускался иногда? Каждую пятницу, 13-го? В день рождения супруга (или супруги)? Или просто каждый час?
#
# В этом случае вам нужен автоматический запуск скриптов, или, как часто его называют программисты, запуск по крону — от английского акронима Cron (англ. Command Run ON) — названия системы для автоматического запуска программ и скриптов на сервере в определённое время.

# %% [markdown]
# ### Автоматический запуск может понадобиться, например:
#
# + если вы хотите с определённой периодичностью скачивать новую информацию с сайтов, например выполнять парсинг новостей для последующего анализа (как мы уже знаем, этот процесс называется web-scraping);
# + если ваш скрипт должен следить за курсом акций и каждую минуту делать запрос по API, чтобы получить новые котировки;
# + если вы написали обучающую платформу и вам нужно каждый час проверять, кто из студентов приступил к занятиям и насколько успешно продвигается их обучение;
# + если у вас есть 500 вендинговых автоматов по продаже солнечных очков и каждые пять минут вы должны опрашивать все автоматы, чтобы узнать, не закончились ли очки.
#
# Примеров может быть очень много. В каждом, даже небольшом, проекте обычно есть 5-10 скриптов, которые с определённой периодичностью обновляют сертификаты доменов, очищают место на диске, считают статистику, генерируют отчёты и так далее. Давайте научимся настраивать запуск этих скриптов в соответствии с задачами, которые стоят перед вами.

# %% [markdown]
# ## КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК

# %% [markdown]
# ### Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют задачей (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль schedule (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль schedule не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %%
import schedule # Импортируем модуль schedule

# %% [markdown]
# ## ПОСТАНОВКА ЗАДАЧИ
#
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %% [markdown]
# ### Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле schedule используется метод every(), который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.
#
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:

# %%
schedule.every(15).minutes.do(task)
# Out:
# Every 15 minutes do task() (last run: [never], next run: 2022-06-09 14:13:22)

# %% [markdown]
# ### Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:

# %%
schedule.every(1).hour.do(task)
# Out:
# Every 1 hour do task() (last run: [never], next run: 2022-06-09 14:58:53)

# %% [markdown]
# ## ВЫПОЛНЕНИЕ ФУНКЦИИ

# %% [markdown]
# ### После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:

# %%
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(15).minutes.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)
